# %%
# цепляю диск
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# логи сюда
# !pip install wandb -qqq
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.9MB 8.0MB/s
#      |████████████████████████████████| 102kB 12.6MB/s
#      |████████████████████████████████| 133kB 39.1MB/s
#      |████████████████████████████████| 163kB 34.3MB/s
#      |████████████████████████████████| 102kB 13.1MB/s
#      |████████████████████████████████| 71kB 12.3MB/s
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# трейн
# !CUDA_VISIBLE_DEVICES=0 python /content/gdrive/MyDrive/Colab/a5/run.py train --train-src=/content/gdrive/MyDrive/Colab/a5/en_es_data/train.es --train-tgt=/content/gdrive/MyDrive/Colab/a5/en_es_data/train.en \
        --dev-src=/content/gdrive/MyDrive/Colab/a5/en_es_data/dev.es --dev-tgt=/content/gdrive/MyDrive/Colab/a5/en_es_data/dev.en --vocab=/content/gdrive/MyDrive/Colab/a5/vocab.json --cuda --use-char-decoder \
        --save-to=/content/gdrive/MyDrive/Colab/a5/model.bin
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# wandb: Currently logged in as: ainurmukh (use `wandb login --relogin` to force relogin)
# 2021-01-12 20:30:34.901324: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# wandb: Tracking run with wandb version 0.10.13
# wandb: Syncing run fresh-sunset-1
# wandb: ⭐️ View project at https://wandb.ai/ainurmukh/lstm_based_nmt_cnn_chardecoder
# wandb: 🚀 View run at https://wandb.ai/ainurmukh/lstm_based_nmt_cnn_chardecoder/runs/2zggaete
# wandb: Run data is saved locally in /content/wandb/run-20210112_203033-2zggaete
# wandb: Run `wandb offline` to turn off syncing.
#
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 2000, cum. loss 272.56, cum. ppl 566757.14 cum. examples 64000
# begin validation ...
# ...

# %%
# !mkdir -p outputs
# !touch /content/gdrive/MyDrive/Colab/a5/outputs/test_outputs.txt
# !CUDA_VISIBLE_DEVICES=0 python /content/gdrive/MyDrive/Colab/a5/run.py decode /content/gdrive/MyDrive/Colab/a5/model.bin /content/gdrive/MyDrive/Colab/a5/en_es_data/test.es /content/gdrive/MyDrive/Colab/a5/en_es_data/test.en /content/gdrive/MyDrive/Colab/a5/outputs/test_outputs.txt \
      --cuda --use-char-decoder --save-to=/content/gdrive/MyDrive/Colab/a5/model.bin
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# load test source sentences from [/content/gdrive/MyDrive/Colab/a5/en_es_data/test.es]
# load test target sentences from [/content/gdrive/MyDrive/Colab/a5/en_es_data/test.en]
# load model from /content/gdrive/MyDrive/Colab/a5/model.bin
# Decoding: 100% 8064/8064 [07:44<00:00, 17.35it/s]
# Corpus BLEU: 36.38971426678862
